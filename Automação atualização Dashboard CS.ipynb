# %%
import pyautogui
import time

pyautogui.alert("ATENÇÃO! Robô Zequinha vai atualizar o Dash, vai tomar uma água.")
pyautogui.PAUSE = 0.8

# abrir opera gx
pyautogui.press('winright')
pyautogui.write('gx')
pyautogui.press('enter')
time.sleep(2)
pyautogui.hotkey('ctrl', 'shift', 'n')
time.sleep(2.5)

# pagina login Hotmart
pyautogui.write('app')
time.sleep(1)
pyautogui.press('enter')
time.sleep(6)

# fazer login
pyautogui.moveTo(203, 290)
pyautogui.click()
pyautogui.write('email1')
pyautogui.press('tab')
pyautogui.write('password1')
pyautogui.press('enter')
time.sleep(4)

# central colaboradores
pyautogui.moveTo(1176, 131)
pyautogui.click()
pyautogui.moveTo(1083, 214)
pyautogui.click()
time.sleep(4)

# acessar pagina assinaturas
pyautogui.moveTo(69, 378)
time.sleep(2)
pyautogui.click()
pyautogui.moveTo(120, 464)
pyautogui.click()
time.sleep(2)
pyautogui.moveTo(1271, 600)
pyautogui.click()

# filtro csv assinatura parte 1
pyautogui.moveTo(1257, 400)
pyautogui.click()
## data 1
pyautogui.moveTo(1141, 490)
pyautogui.click()
pyautogui.hotkey('ctrl', 'a')
pyautogui.write('01/01/2021')
## status assinatura
pyautogui.scroll(-1000)
pyautogui.moveTo(1166, 387)
pyautogui.click()
pyautogui.moveTo(1119, 428)
pyautogui.click()
pyautogui.click()
pyautogui.moveTo(1108, 462)
pyautogui.click()
pyautogui.moveTo(1108, 508)
pyautogui.click()
pyautogui.moveTo(1108, 557)
pyautogui.click()
pyautogui.moveTo(1108, 583)
pyautogui.click()
pyautogui.moveTo(1218, 692)
pyautogui.click()
time.sleep(6)

# baixar CSV assinatura parte 1
pyautogui.moveTo(891, 447)
pyautogui.click()
pyautogui.moveTo(1171, 402)
pyautogui.click()
time.sleep(6)

# filtro csv assinatura parte 2
pyautogui.moveTo(1257, 400)
pyautogui.click()
pyautogui.moveTo(1141, 490)
pyautogui.scroll(1000)
## data 1
pyautogui.click()
pyautogui.hotkey('ctrl', 'a')
pyautogui.write('27/11/2019')
## data 2
pyautogui.moveTo(1261, 490)
pyautogui.click()
pyautogui.hotkey('ctrl', 'a')
pyautogui.write('31/12/2020')
pyautogui.moveTo(1218, 692)
pyautogui.click()
time.sleep(6)

# baixar CSV assinatura parte 2
pyautogui.moveTo(891, 447)
pyautogui.click()
pyautogui.moveTo(1171, 402)
pyautogui.click()
time.sleep(6)

# acessar pagina vendas
pyautogui.moveTo(69, 378)
time.sleep(2)
pyautogui.moveTo(115, 431)
pyautogui.click()
time.sleep(5)

# filtro csv reembolso
pyautogui.moveTo(1257, 400)
pyautogui.click()
## data 1
pyautogui.moveTo(1141, 490)
pyautogui.click()
pyautogui.hotkey('ctrl', 'a')
pyautogui.write('27/11/2019')
## status transação
pyautogui.moveTo(1347, 294)
pyautogui.mouseDown()
pyautogui.moveTo(1347, 450)
pyautogui.mouseUp()
pyautogui.moveTo(1119, 294)
pyautogui.click()
pyautogui.click()
pyautogui.moveTo(1108, 569)
pyautogui.click()
## produto
pyautogui.moveTo(1202, 199)
pyautogui.click()
pyautogui.write('yampa - software')
pyautogui.moveTo(1200, 253)
pyautogui.click()
pyautogui.moveTo(1218, 692)
pyautogui.click()
time.sleep(6)

# baixar CSV reembolso
pyautogui.moveTo(891, 447)
pyautogui.click()
pyautogui.moveTo(1171, 402)
pyautogui.click()
pyautogui.moveTo(1070, 527)
pyautogui.click()
time.sleep(6)

# deslogar
pyautogui.moveTo(1157, 227)
pyautogui.click()
pyautogui.moveTo(1323, 131)
pyautogui.click()
time.sleep(3)
pyautogui.click()
pyautogui.moveTo(1229, 222)
pyautogui.click()
time.sleep(3)

# fazer login 2
pyautogui.moveTo(203, 290)
pyautogui.click()
pyautogui.write('email2')
pyautogui.press('tab')
pyautogui.write('password2')
pyautogui.press('enter')
time.sleep(4)

# acessar pagina assinaturas
pyautogui.moveTo(74, 451)
time.sleep(2)
pyautogui.click()
pyautogui.moveTo(120, 535)
pyautogui.click()
time.sleep(2)
pyautogui.moveTo(1150, 449)
pyautogui.click()

# filtro csv assinatura 
pyautogui.moveTo(1257, 400)
pyautogui.click()
## data 1
pyautogui.moveTo(1141, 490)
pyautogui.click()
pyautogui.hotkey('ctrl', 'a')
pyautogui.write('01/02/2019')
## status assinatura
pyautogui.scroll(-1000)
pyautogui.moveTo(1166, 387)
pyautogui.click()
pyautogui.moveTo(1119, 428)
pyautogui.click()
pyautogui.click()
pyautogui.moveTo(1108, 462)
pyautogui.click()
pyautogui.moveTo(1108, 508)
pyautogui.click()
pyautogui.moveTo(1108, 557)
pyautogui.click()
pyautogui.moveTo(1108, 583)
pyautogui.click()
pyautogui.moveTo(1218, 692)
pyautogui.click()
time.sleep(6)

# baixar CSV assinatura
pyautogui.moveTo(891, 447)
pyautogui.click()
pyautogui.moveTo(1171, 402)
pyautogui.click()
time.sleep(6)

# acessar pagina vendas
pyautogui.moveTo(69, 450)
time.sleep(2)
pyautogui.moveTo(93, 502)
pyautogui.click()
time.sleep(5)

# filtro csv reembolso
pyautogui.moveTo(1257, 400)
pyautogui.click()
## data 1
pyautogui.moveTo(1141, 490)
pyautogui.click()
pyautogui.hotkey('ctrl', 'a')
pyautogui.write('01/02/2019')
## status transação
pyautogui.moveTo(1347, 294)
pyautogui.mouseDown()
pyautogui.moveTo(1347, 450)
pyautogui.mouseUp()
pyautogui.moveTo(1119, 294)
pyautogui.click()
pyautogui.click()
pyautogui.moveTo(1108, 569)
pyautogui.click()
pyautogui.moveTo(1218, 692)
pyautogui.click()
time.sleep(6)

# baixar CSV reembolso
pyautogui.moveTo(891, 447)
pyautogui.click()
pyautogui.moveTo(1171, 402)
pyautogui.click()
pyautogui.moveTo(1070, 527)
pyautogui.click()
time.sleep(6)

# deslogar
pyautogui.moveTo(1157, 227)
pyautogui.click()
pyautogui.moveTo(1323, 131)
pyautogui.click()
pyautogui.moveTo(1229, 222)
pyautogui.click()
time.sleep(4)

# fechar aba anonima
pyautogui.moveTo(1345, 17)
pyautogui.click()

# acessar Dashboard
pyautogui.moveTo(1196, 80)
pyautogui.click()
time.sleep(8)

# abrir aba para importar assinaturas
pyautogui.moveTo(443, 708)
pyautogui.click()
pyautogui.moveTo(96, 706)
pyautogui.click()

# importar csv assinatura hotmart nova parte 1
## arquivo
pyautogui.moveTo(134, 147)
pyautogui.click()
##importar
pyautogui.moveTo(187, 302)
pyautogui.click()
time.sleep(2)
## upload
pyautogui.moveTo(718, 225)
pyautogui.click()
## botao selecionar arquivo
pyautogui.moveTo(707, 464)
pyautogui.click()
pyautogui.moveTo(814, 399)
pyautogui.click()
time.sleep(1.5)
## seleciona arquivo pasta downloads
pyautogui.moveTo(341, 255)
pyautogui.click()
pyautogui.moveTo(515, 446)
pyautogui.click()
time.sleep(4)
## anexar a pagina atual
pyautogui.moveTo(528, 426)
pyautogui.click()
pyautogui.moveTo(554, 549)
pyautogui.click()
## ponto e virgula
pyautogui.moveTo(734, 422)
pyautogui.click()
pyautogui.moveTo(824, 515)
pyautogui.click()
pyautogui.moveTo(485, 492)
pyautogui.click()
pyautogui.write(';')
## importar dados
pyautogui.moveTo(734, 610)
pyautogui.click()
time.sleep(3)

# adicionar nova linha para importar
pyautogui.hotkey('ctrl','down')
pyautogui.hotkey('ctrl','down')
pyautogui.moveTo(244, 651)
pyautogui.click()
pyautogui.press('backspace', presses=3)
pyautogui.moveTo(132, 654)
pyautogui.click()
pyautogui.hotkey('ctrl','down')

# importar csv assinatura hotmart nova parte 2
## arquivo
pyautogui.moveTo(134, 147)
pyautogui.click()
##importar
pyautogui.moveTo(187, 302)
pyautogui.click()
time.sleep(2)
## upload
pyautogui.moveTo(718, 225)
pyautogui.click()
## botao selecionar arquivo
pyautogui.moveTo(707, 464)
pyautogui.click()
pyautogui.moveTo(814, 399)
pyautogui.click()
time.sleep(1.5)
## seleciona arquivo pasta downloads
pyautogui.moveTo(341, 235)
pyautogui.click()
pyautogui.moveTo(515, 446)
pyautogui.click()
time.sleep(4)
## anexar a pagina atual
pyautogui.moveTo(528, 426)
pyautogui.click()
pyautogui.moveTo(554, 549)
pyautogui.click()
## ponto e virgula
pyautogui.moveTo(734, 422)
pyautogui.click()
pyautogui.moveTo(824, 515)
pyautogui.click()
pyautogui.moveTo(485, 492)
pyautogui.click()
pyautogui.write(';')
## importar dados
pyautogui.moveTo(734, 610)
pyautogui.click()
time.sleep(3)

# apagar linha cabeçalho
pyautogui.moveTo(68, 623)
pyautogui.click(button='right')
pyautogui.moveTo(146, 390)
pyautogui.click()

# adicionar nova linha para importar
pyautogui.hotkey('ctrl','down')
pyautogui.hotkey('ctrl','down')
pyautogui.moveTo(132, 654)
pyautogui.click()
pyautogui.hotkey('ctrl','down')

# importar csv assinatura hotmart antiga
## arquivo
pyautogui.moveTo(134, 147)
pyautogui.click()
##importar
pyautogui.moveTo(187, 302)
pyautogui.click()
time.sleep(2)
## upload
pyautogui.moveTo(718, 225)
pyautogui.click()
## botao selecionar arquivo
pyautogui.moveTo(707, 464)
pyautogui.click()
pyautogui.moveTo(814, 399)
pyautogui.click()
time.sleep(1.5)
## seleciona arquivo pasta downloads
pyautogui.moveTo(341, 195)
pyautogui.click()
pyautogui.moveTo(515, 446)
pyautogui.click()
time.sleep(4)
## anexar a pagina atual
pyautogui.moveTo(528, 426)
pyautogui.click()
pyautogui.moveTo(554, 549)
pyautogui.click()
## ponto e virgula
pyautogui.moveTo(734, 422)
pyautogui.click()
pyautogui.moveTo(824, 515)
pyautogui.click()
pyautogui.moveTo(485, 492)
pyautogui.click()
pyautogui.write(';')
## importar dados
pyautogui.moveTo(734, 610)
pyautogui.click()
time.sleep(3)

# apagar linha cabeçalho
pyautogui.moveTo(68, 623)
pyautogui.click(button='right')
pyautogui.moveTo(146, 390)
pyautogui.click()

# adicionar filtro
pyautogui.hotkey('ctrl','up')
pyautogui.moveTo(63, 239)
pyautogui.click()
pyautogui.moveTo(1115, 185)
pyautogui.click()

# filtrar data adesão
pyautogui.moveTo(782, 264)
pyautogui.click()
pyautogui.moveTo(635, 290)
pyautogui.click()
time.sleep(3)

# selecionar tudo e copiar
pyautogui.moveTo(118, 260)
pyautogui.click()
pyautogui.keyDown('shiftleft')
pyautogui.keyDown('shiftright')
pyautogui.hotkey('ctrl','right')
pyautogui.hotkey('ctrl','down')
pyautogui.keyUp('shiftleft')
pyautogui.keyUp('shiftright')
pyautogui.hotkey('ctrl','c')
time.sleep(5)

# colar na aba base assinaturas
pyautogui.moveTo(429, 705)
pyautogui.click()
pyautogui.moveTo(490, 260)
pyautogui.click()
pyautogui.hotkey('ctrl','v')
time.sleep(8)

# abrir aba para importar reembolsos
pyautogui.moveTo(96, 706)
pyautogui.click()

# importar csv reembolso hotmart nova
## arquivo
pyautogui.moveTo(134, 147)
pyautogui.click()
##importar
pyautogui.moveTo(187, 302)
pyautogui.click()
time.sleep(2)
## upload
pyautogui.moveTo(718, 225)
pyautogui.click()
## botao selecionar arquivo
pyautogui.moveTo(707, 464)
pyautogui.click()
pyautogui.moveTo(814, 399)
pyautogui.click()
time.sleep(1.5)
## seleciona arquivo pasta downloads
pyautogui.moveTo(341, 215)
pyautogui.click()
pyautogui.moveTo(515, 446)
pyautogui.click()
time.sleep(4)
## anexar a pagina atual
pyautogui.moveTo(528, 426)
pyautogui.click()
pyautogui.moveTo(554, 549)
pyautogui.click()
## ponto e virgula
pyautogui.moveTo(734, 422)
pyautogui.click()
pyautogui.moveTo(824, 515)
pyautogui.click()
pyautogui.moveTo(485, 492)
pyautogui.click()
pyautogui.write(';')
## importar dados
pyautogui.moveTo(734, 610)
pyautogui.click()
time.sleep(3)

# adicionar nova linha para importar
pyautogui.hotkey('ctrl','down')
pyautogui.press('down')

# importar csv reembolso hotmart antiga
## arquivo
pyautogui.moveTo(134, 147)
pyautogui.click()
##importar
pyautogui.moveTo(187, 302)
pyautogui.click()
time.sleep(2)
## upload
pyautogui.moveTo(718, 225)
pyautogui.click()
## botao selecionar arquivo
pyautogui.moveTo(707, 464)
pyautogui.click()
pyautogui.moveTo(814, 399)
pyautogui.click()
time.sleep(1.5)
## seleciona arquivo pasta downloads
pyautogui.moveTo(341, 175)
pyautogui.click()
pyautogui.moveTo(515, 446)
pyautogui.click()
time.sleep(4)
## anexar a pagina atual
pyautogui.moveTo(528, 426)
pyautogui.click()
pyautogui.moveTo(554, 549)
pyautogui.click()
## ponto e virgula
pyautogui.moveTo(734, 422)
pyautogui.click()
pyautogui.moveTo(824, 515)
pyautogui.click()
pyautogui.moveTo(485, 492)
pyautogui.click()
pyautogui.write(';')
## importar dados
pyautogui.moveTo(734, 610)
pyautogui.click()
time.sleep(3)

# apagar linha cabeçalho
pyautogui.moveTo(65, 664)
pyautogui.click(button='right')
pyautogui.moveTo(146, 390)
pyautogui.click()

# adicionar filtro
pyautogui.hotkey('ctrl','up')
pyautogui.moveTo(63, 239)
pyautogui.click()
pyautogui.moveTo(1115, 185)
pyautogui.click()

# filtrar data adesão
pyautogui.moveTo(135, 265)
pyautogui.click()
pyautogui.moveTo(244, 681)
pyautogui.mouseDown()
pyautogui.moveTo(500, 681)
pyautogui.mouseUp()
pyautogui.moveTo(680, 262)
pyautogui.click()
pyautogui.press('down')
pyautogui.press('enter')
time.sleep(3)
pyautogui.press('home')

# selecionar tudo e copiar
pyautogui.moveTo(118, 260)
pyautogui.click()
pyautogui.keyDown('shiftleft')
pyautogui.keyDown('shiftright')
pyautogui.hotkey('ctrl','right')
pyautogui.hotkey('ctrl','down')
pyautogui.keyUp('shiftleft')
pyautogui.keyUp('shiftright')
pyautogui.hotkey('ctrl','c')
time.sleep(5)

# colar na aba base assinaturas
pyautogui.moveTo(825, 705)
pyautogui.click()
pyautogui.moveTo(400, 260)
pyautogui.click()
pyautogui.hotkey('ctrl','v')
time.sleep(5)

# apagar abas
pyautogui.moveTo(685, 705)
pyautogui.click(button='right')
pyautogui.moveTo(710, 358)
pyautogui.click()
pyautogui.moveTo(925, 455)
pyautogui.click()
pyautogui.moveTo(580, 705)
pyautogui.click(button='right')
pyautogui.moveTo(610, 358)
pyautogui.click()
pyautogui.moveTo(925, 455)
pyautogui.click()

# abrir Dashboard
pyautogui.moveTo(250, 705)
pyautogui.click()

pyautogui.alert("Dashboard atualizado com sucesso! ;)")

# %%
## data 1
pyautogui.moveTo(1141, 490)
pyautogui.click()
pyautogui.hotkey('ctrl', 'a')
pyautogui.write('27/11/2019')
## data 2'
pyautogui.moveTo(1261, 490)
pyautogui.click()
pyautogui.hotkey('ctrl', 'a')
pyautogui.write('31/12/2019')

# %%
pyautogui.hotkey('alt', 'tab') 

# acessar Dashboard
pyautogui.moveTo(1196, 80)
pyautogui.click()
time.sleep(8)

# abrir aba para importar assinaturas
pyautogui.moveTo(443, 708)
pyautogui.click()
pyautogui.moveTo(96, 706)
pyautogui.click()

# importar csv assinatura hotmart nova parte 1
## arquivo
pyautogui.moveTo(134, 147)
pyautogui.click()
##importar
pyautogui.moveTo(187, 302)
pyautogui.click()
time.sleep(2)
## upload
pyautogui.moveTo(718, 225)
pyautogui.click()
## botao selecionar arquivo
pyautogui.moveTo(707, 464)
pyautogui.click()
pyautogui.moveTo(814, 399)
pyautogui.click()
time.sleep(1.5)
## entrar na pasta downloads
pyautogui.moveTo(364,60)
pyautogui.click()
pyautogui.write(r'C:\Users\jheff\Downloads')
pyautogui.press('enter')
pyautogui.moveTo(460,280)
pyautogui.scroll(1000)
## seleciona arquivo pasta downloads
pyautogui.moveTo(341, 255)
pyautogui.click()
pyautogui.moveTo(515, 446)
pyautogui.click()
time.sleep(4)
## anexar a pagina atual
pyautogui.moveTo(528, 426)
pyautogui.click()
pyautogui.moveTo(554, 549)
pyautogui.click()
## ponto e virgula
pyautogui.moveTo(734, 422)
pyautogui.click()
pyautogui.moveTo(824, 515)
pyautogui.click()
pyautogui.moveTo(485, 492)
pyautogui.click()
pyautogui.write(';')
## importar dados
pyautogui.moveTo(734, 610)
pyautogui.click()
time.sleep(3)

# adicionar nova linha para importar
pyautogui.hotkey('ctrl','down')
pyautogui.hotkey('ctrl','down')
pyautogui.moveTo(244, 651)
pyautogui.click()
pyautogui.press('backspace', presses=3)
pyautogui.moveTo(132, 654)
pyautogui.click()
pyautogui.hotkey('ctrl','down')

# importar csv assinatura hotmart nova parte 2
## arquivo
pyautogui.moveTo(134, 147)
pyautogui.click()
##importar
pyautogui.moveTo(187, 302)
pyautogui.click()
time.sleep(2)
## upload
pyautogui.moveTo(718, 225)
pyautogui.click()
## botao selecionar arquivo
pyautogui.moveTo(707, 464)
pyautogui.click()
pyautogui.moveTo(814, 399)
pyautogui.click()
time.sleep(1.5)
## seleciona arquivo pasta downloads
pyautogui.moveTo(341, 235)
pyautogui.click()
pyautogui.moveTo(515, 446)
pyautogui.click()
time.sleep(4)
## anexar a pagina atual
pyautogui.moveTo(528, 426)
pyautogui.click()
pyautogui.moveTo(554, 549)
pyautogui.click()
## ponto e virgula
pyautogui.moveTo(734, 422)
pyautogui.click()
pyautogui.moveTo(824, 515)
pyautogui.click()
pyautogui.moveTo(485, 492)
pyautogui.click()
pyautogui.write(';')
## importar dados
pyautogui.moveTo(734, 610)
pyautogui.click()
time.sleep(3)

# apagar linha cabeçalho
pyautogui.moveTo(68, 623)
pyautogui.click(button='right')
pyautogui.moveTo(146, 390)
pyautogui.click()

# adicionar nova linha para importar
pyautogui.hotkey('ctrl','down')
pyautogui.hotkey('ctrl','down')
pyautogui.moveTo(132, 654)
pyautogui.click()
pyautogui.hotkey('ctrl','down')

# importar csv assinatura hotmart antiga
## arquivo
pyautogui.moveTo(134, 147)
pyautogui.click()
##importar
pyautogui.moveTo(187, 302)
pyautogui.click()
time.sleep(2)
## upload
pyautogui.moveTo(718, 225)
pyautogui.click()
## botao selecionar arquivo
pyautogui.moveTo(707, 464)
pyautogui.click()
pyautogui.moveTo(814, 399)
pyautogui.click()
time.sleep(1.5)
## seleciona arquivo pasta downloads
pyautogui.moveTo(341, 195)
pyautogui.click()
pyautogui.moveTo(515, 446)
pyautogui.click()
time.sleep(4)
## anexar a pagina atual
pyautogui.moveTo(528, 426)
pyautogui.click()
pyautogui.moveTo(554, 549)
pyautogui.click()
## ponto e virgula
pyautogui.moveTo(734, 422)
pyautogui.click()
pyautogui.moveTo(824, 515)
pyautogui.click()
pyautogui.moveTo(485, 492)
pyautogui.click()
pyautogui.write(';')
## importar dados
pyautogui.moveTo(734, 610)
pyautogui.click()
time.sleep(3)

# apagar linha cabeçalho
pyautogui.moveTo(68, 623)
pyautogui.click(button='right')
pyautogui.moveTo(146, 390)
pyautogui.click()

# adicionar filtro
pyautogui.hotkey('ctrl','up')
pyautogui.moveTo(63, 239)
pyautogui.click()
pyautogui.moveTo(1115, 185)
pyautogui.click()

# filtrar data adesão
pyautogui.moveTo(782, 264)
pyautogui.click()
pyautogui.moveTo(635, 290)
pyautogui.click()
time.sleep(3)

# selecionar tudo e copiar
pyautogui.moveTo(118, 260)
pyautogui.click()
pyautogui.keyDown('shiftleft')
pyautogui.keyDown('shiftright')
pyautogui.hotkey('ctrl','right')
pyautogui.hotkey('ctrl','down')
pyautogui.keyUp('shiftleft')
pyautogui.keyUp('shiftright')
pyautogui.hotkey('ctrl','c')
time.sleep(5)

# colar na aba base assinaturas
pyautogui.moveTo(429, 705)
pyautogui.click()
pyautogui.moveTo(490, 260)
pyautogui.click()
pyautogui.hotkey('ctrl','v')
time.sleep(8)

# abrir aba para importar reembolsos
pyautogui.moveTo(96, 706)
pyautogui.click()

# importar csv reembolso hotmart nova
## arquivo
pyautogui.moveTo(134, 147)
pyautogui.click()
##importar
pyautogui.moveTo(187, 302)
pyautogui.click()
time.sleep(2)
## upload
pyautogui.moveTo(718, 225)
pyautogui.click()
## botao selecionar arquivo
pyautogui.moveTo(707, 464)
pyautogui.click()
pyautogui.moveTo(814, 399)
pyautogui.click()
time.sleep(1.5)
## seleciona arquivo pasta downloads
pyautogui.moveTo(341, 215)
pyautogui.click()
pyautogui.moveTo(515, 446)
pyautogui.click()
time.sleep(4)
## anexar a pagina atual
pyautogui.moveTo(528, 426)
pyautogui.click()
pyautogui.moveTo(554, 549)
pyautogui.click()
## ponto e virgula
pyautogui.moveTo(734, 422)
pyautogui.click()
pyautogui.moveTo(824, 515)
pyautogui.click()
pyautogui.moveTo(485, 492)
pyautogui.click()
pyautogui.write(';')
## importar dados
pyautogui.moveTo(734, 610)
pyautogui.click()
time.sleep(3)

# adicionar nova linha para importar
pyautogui.hotkey('ctrl','down')
pyautogui.press('down')

# importar csv reembolso hotmart antiga
## arquivo
pyautogui.moveTo(134, 147)
pyautogui.click()
##importar
pyautogui.moveTo(187, 302)
pyautogui.click()
time.sleep(2)
## upload
pyautogui.moveTo(718, 225)
pyautogui.click()
## botao selecionar arquivo
pyautogui.moveTo(707, 464)
pyautogui.click()
pyautogui.moveTo(814, 399)
pyautogui.click()
time.sleep(1.5)
## seleciona arquivo pasta downloads
pyautogui.moveTo(341, 175)
pyautogui.click()
pyautogui.moveTo(515, 446)
pyautogui.click()
time.sleep(4)
## anexar a pagina atual
pyautogui.moveTo(528, 426)
pyautogui.click()
pyautogui.moveTo(554, 549)
pyautogui.click()
## ponto e virgula
pyautogui.moveTo(734, 422)
pyautogui.click()
pyautogui.moveTo(824, 515)
pyautogui.click()
pyautogui.moveTo(485, 492)
pyautogui.click()
pyautogui.write(';')
## importar dados
pyautogui.moveTo(734, 610)
pyautogui.click()
time.sleep(3)

# apagar linha cabeçalho
pyautogui.moveTo(65, 664)
pyautogui.click(button='right')
pyautogui.moveTo(146, 390)
pyautogui.click()

# adicionar filtro
pyautogui.hotkey('ctrl','up')
pyautogui.moveTo(63, 239)
pyautogui.click()
pyautogui.moveTo(1115, 185)
pyautogui.click()

# filtrar data adesão
pyautogui.moveTo(135, 265)
pyautogui.click()
pyautogui.moveTo(244, 681)
pyautogui.mouseDown()
pyautogui.moveTo(500, 681)
pyautogui.mouseUp()
pyautogui.moveTo(680, 262)
pyautogui.click()
pyautogui.press('down')
pyautogui.press('enter')
time.sleep(3)
pyautogui.press('home')

# selecionar tudo e copiar
pyautogui.moveTo(118, 260)
pyautogui.click()
pyautogui.keyDown('shiftleft')
pyautogui.keyDown('shiftright')
pyautogui.hotkey('ctrl','right')
pyautogui.hotkey('ctrl','down')
pyautogui.keyUp('shiftleft')
pyautogui.keyUp('shiftright')
pyautogui.hotkey('ctrl','c')
time.sleep(5)

# colar na aba base assinaturas
pyautogui.moveTo(825, 705)
pyautogui.click()
pyautogui.moveTo(400, 260)
pyautogui.click()
pyautogui.hotkey('ctrl','v')
time.sleep(5)

# apagar abas
pyautogui.moveTo(685, 705)
pyautogui.click(button='right')
pyautogui.moveTo(710, 358)
pyautogui.click()
pyautogui.moveTo(925, 455)
pyautogui.click()
pyautogui.moveTo(580, 705)
pyautogui.click(button='right')
pyautogui.moveTo(610, 358)
pyautogui.click()
pyautogui.moveTo(925, 455)
pyautogui.click()

# abrir ;
pyautogui.moveTo(250, 705)
pyautogui.click()

pyautogui.alert("Dashboard atualizado com sucesso! ;)")
# Out:
# 'OK'
